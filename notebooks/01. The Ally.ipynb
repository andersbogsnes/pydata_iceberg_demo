# %% [markdown]
# # The Ally - DuckDB
#
# ![Duckdb logo](images/duckdb_logo.png)

# %%
import duckdb

# %%
sql = "SELECT * FROM '../data/csv/10.csv' LIMIT 2"

# %% [markdown]
# # DB-API 2.0 style

# %%
with duckdb.connect('demo.ddb') as conn:
    r = conn.execute(sql)
    results = list(r.fetchall())

# %%
results
# Out:
# [(147937429,
#   'english',
#   1696875102,
#   1717510986,
#   1,
#   3,
#   0,
#   0.5267999172210693,
#   0,
#   1,
#   0,
#   0,
#   1,
#   None,
#   76561199550893216,
#   35,
#   23,
#   59161,
#   4738,
#   58753,
#   1717541057),
#  (166664841,
#   'russian',
#   1717510100,
#   1717510100,
#   1,
#   0,
#   0,
#   0.0,
#   0,
#   1,
#   0,
#   0,
#   1,
#   None,
#   76561199161536896,
#   24,
#   11,
#   436,
#   71,
#   385,
#   1717512997)]

# %% [markdown]
# ## To Pandas

# %%
with duckdb.connect('demo.ddb') as conn:
    df = conn.sql(sql).df()

# %%
df
# Out:
#    recommendationid language  timestamp_created  timestamp_updated  voted_up  \
# 0         147937429  english         1696875102         1717510986         1
# 1         166664841  russian         1717510100         1717510100         1
#
#    votes_up  votes_funny  weighted_vote_score  comment_count  steam_purchase  \
# 0         3            0               0.5268              0               1
# 1         0            0               0.0000              0               1
#
#    ...  written_during_early_access  hidden_in_steam_china  \
# 0  ...                            0                      1
# 1  ...                            0                      1
#
#    steam_china_location     author_steamid  author_num_games_owned  \
# 0                  None  76561199550893216                      35
# 1                  None  76561199161536896                      24
#
#    author_num_reviews  author_playtime_forever  \
# 0                  23                    59161
# 1                  11                      436
#
#    author_playtime_last_two_weeks  author_playtime_at_review  \
# 0                            4738                      58753
# 1                              71                        385
#
#    author_last_played
# 0          1717541057
# 1          1717512997
#
# [2 rows x 21 columns]

# %% [markdown]
# ## To Polars

# %%
with duckdb.connect('demo.ddb') as conn:
    polars_df = conn.sql(sql).pl()

# %%
polars_df
# Out:
# shape: (2, 21)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ recommend ┆ language ┆ timestamp ┆ timestamp ┆ … ┆ author_pl ┆ author_pl ┆ author_pl ┆ author_la │
# │ ationid   ┆ ---      ┆ _created  ┆ _updated  ┆   ┆ aytime_fo ┆ aytime_la ┆ aytime_at ┆ st_played │
# │ ---       ┆ str      ┆ ---       ┆ ---       ┆   ┆ rever     ┆ st_two_we ┆ _review   ┆ ---       │
# │ i64       ┆          ┆ i64       ┆ i64       ┆   ┆ ---       ┆ eks       ┆ ---       ┆ i64       │
# │           ┆          ┆           ┆           ┆   ┆ i64       ┆ ---       ┆ i64       ┆           │
# │           ┆          ┆           ┆           ┆   ┆           ┆ i64       ┆           ┆           │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 147937429 ┆ english  ┆ 169687510 ┆ 171751098 ┆ … ┆ 59161     ┆ 4738      ┆ 58753     ┆ 171754105 │
# │           ┆          ┆ 2         ┆ 6         ┆   ┆           ┆           ┆           ┆ 7         │
# │ 166664841 ┆ russian  ┆ 171751010 ┆ 171751010 ┆ … ┆ 436       ┆ 71        ┆ 385       ┆ 171751299 │
# │           ┆          ┆ 0         ┆ 0         ┆   ┆           ┆           ┆           ┆ 7         │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## To Arrow

# %%
with duckdb.connect('demo.ddb') as conn:
    arrow_table = conn.sql(sql).arrow()

# %%
arrow_table
# Out:
# pyarrow.Table
# recommendationid: int64
# language: string
# timestamp_created: int64
# timestamp_updated: int64
# voted_up: int64
# votes_up: int64
# votes_funny: int64
# weighted_vote_score: double
# comment_count: int64
# steam_purchase: int64
# received_for_free: int64
# written_during_early_access: int64
# hidden_in_steam_china: int64
# steam_china_location: string
# author_steamid: int64
# author_num_games_owned: int64
# author_num_reviews: int64
# author_playtime_forever: int64
# author_playtime_last_two_weeks: int64
# author_playtime_at_review: int64
# author_last_played: int64
# ----
# recommendationid: [[147937429,166664841]]
# language: [["english","russian"]]
# timestamp_created: [[1696875102,1717510100]]
# timestamp_updated: [[1717510986,1717510100]]
# voted_up: [[1,1]]
# votes_up: [[3,0]]
# votes_funny: [[0,0]]
# weighted_vote_score: [[0.5267999172210693,0]]
# comment_count: [[0,0]]
# steam_purchase: [[1,1]]
# ...

# %% [markdown]
# # Relation style

# %%
rel = duckdb.read_csv("../data/csv/10.csv")

# %%
duckdb.sql('select COUNT(*) from rel as num_reviews').show()
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       238828 │
# └──────────────┘

# %%
rel.limit(10).show()
# Out:
# ┌──────────────────┬───────────┬───┬──────────────────────┬──────────────────────┬────────────────────┐
# │ recommendationid │ language  │ … │ author_playtime_la…  │ author_playtime_at…  │ author_last_played │
# │      int64       │  varchar  │   │        int64         │        int64         │       int64        │
# ├──────────────────┼───────────┼───┼──────────────────────┼──────────────────────┼────────────────────┤
# │        147937429 │ english   │ … │                 4738 │                58753 │         1717541057 │
# │        166664841 │ russian   │ … │                   71 │                  385 │         1717512997 │
# │        166664763 │ russian   │ … │                    7 │                23743 │         1717510490 │
# │        166663001 │ turkish   │ … │                   19 │                  356 │         1717508513 │
# │        166658743 │ brazilian │ … │                    0 │                 1497 │         1478272196 │
# │        161810892 │ schinese  │ … │                  524 │                  599 │         1717505337 │
# │        166652969 │ english   │ … │                  502 │                13426 │         1717500702 │
# │        166652933 │ english   │ … │                    0 │                 3197 │         1714457233 │
# │        155639835 │ russian   │ … │                  238 │                 1928 │         1717501130 │
# │        166651422 │ russian   │ … │                    0 │                    7 │         1710513489 │
# ├──────────────────┴───────────┴───┴──────────────────────┴──────────────────────┴────────────────────┤
# │ 10 rows                                                                        21 columns (5 shown) │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
rel.select('recommendationid', "language", 'voted_up').filter("language = 'english'").limit(10).show()
# Out:
# ┌──────────────────┬──────────┬──────────┐
# │ recommendationid │ language │ voted_up │
# │      int64       │ varchar  │  int64   │
# ├──────────────────┼──────────┼──────────┤
# │        147937429 │ english  │        1 │
# │        166652969 │ english  │        1 │
# │        166652933 │ english  │        1 │
# │        137537621 │ english  │        1 │
# │        154253089 │ english  │        1 │
# │        166638678 │ english  │        1 │
# │        166638235 │ english  │        1 │
# │        127794149 │ english  │        1 │
# │        166629955 │ english  │        1 │
# │        166623062 │ english  │        1 │
# ├──────────────────┴──────────┴──────────┤
# │ 10 rows                      3 columns │
# └────────────────────────────────────────┘

# %% [markdown]
# ## In-memory sharing

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/csv/10.csv')

# %%
df.tail(10)
# Out:
#         recommendationid    language  timestamp_created  timestamp_updated  \
# 238818        15043110.0     english         1427259949         1571474648
# 238819        13639509.0     russian         1419695652         1419695652
# 238820        13140541.0  portuguese         1417265132         1417265132
# 238821        10349773.0     russian         1401920934         1623438450
# 238822         8227337.0      polish         1387815443         1387815443
# 238823               NaN  1351380029                  1                  0
# 238824       149330962.0     russian         1698868683         1698868683
# 238825       149284037.0     english         1698800321         1698800321
# 238826       127959835.0    schinese         1670214704         1698915106
# 238827         1092034.0     english         1291918689         1291918689
#
#         voted_up  votes_up  votes_funny  weighted_vote_score  comment_count  \
# 238818         1         0            0                  0.0              0
# 238819         1         0            0                  0.0              0
# 238820         1         0            0                  0.0              0
# 238821         1         0            1                  0.0              0
# 238822         1         0            0                  0.0              0
# 238823         0         0            0                  1.0              0
# 238824         1         0            0                  0.0              0
# 238825         1         0            0                  0.0              0
# 238826         1         0            0                  0.0              0
# 238827         1         0            0                  0.0              0
#
#         steam_purchase  ...  written_during_early_access  \
# 238818               0  ...                          0.0
# 238819               0  ...                          0.0
# 238820               0  ...                          0.0
# 238821               0  ...                          0.0
# 238822               0  ...                          0.0
# 238823               0  ...                          NaN
# 238824               1  ...                          0.0
# 238825               0  ...                          0.0
# 238826               1  ...                          0.0
# 238827               0  ...                          0.0
#
#         hidden_in_steam_china  steam_china_location     author_steamid  \
# 238818                      0                   NaN  76561198072567552
# 238819                      0                   NaN  76561198124826128
# 238820                      0                   NaN  76561198055582432
# 238821                      0                   NaN  76561198036529024
# 238822                      0                   NaN  76561198054766880
# 238823      76561198008269840                   0.0                  2
# 238824                      1                   NaN  76561199093871104
# 238825                      1                   NaN  76561199052025216
# 238826                      1                   NaN  76561199209656688
# 238827                      0                   NaN  76561197986485904
#
#         author_num_games_owned  author_num_reviews  author_playtime_forever  \
# 238818                      38                  34                     7302
# 238819                     176                   4                     5124
# 238820                       0                   3                     4013
# 238821                       0                  12                    20892
# 238822                     114                   2                    68669
# 238823                   95521                   0                    37952
# 238824                      62                  26                       29
# 238825                      46                   3                     3367
# 238826                      47                  11                     1179
# 238827                       0                   2                   119070
#
#         author_playtime_last_two_weeks  author_playtime_at_review  \
# 238818                               0                     4661.0
# 238819                               0                     4463.0
# 238820                               0                     1998.0
# 238821                             592                    16575.0
# 238822                               0                    47901.0
# 238823                      1547225350                        NaN
# 238824                              10                       29.0
# 238825                            2694                     3016.0
# 238826                               0                     1179.0
# 238827                               0                   116910.0
#
#         author_last_played
# 238818        1.571062e+09
# 238819        1.631001e+09
# 238820        1.587926e+09
# 238821        1.698087e+09
# 238822        1.524517e+09
# 238823                 NaN
# 238824        1.698427e+09
# 238825        1.698892e+09
# 238826        1.694818e+09
# 238827        1.396685e+09
#
# [10 rows x 21 columns]

# %%
duckdb.sql('select recommendationid, voted_up, timestamp_created from df limit 2').show()
# Out:
# ┌──────────────────┬──────────┬───────────────────┐
# │ recommendationid │ voted_up │ timestamp_created │
# │      double      │  int64   │       int64       │
# ├──────────────────┼──────────┼───────────────────┤
# │      147937429.0 │        1 │        1696875102 │
# │      166664841.0 │        1 │        1717510100 │
# └──────────────────┴──────────┴───────────────────┘

# %%
df[['recommendationid', 'voted_up', 'timestamp_created']].head(2)
# Out:
#    recommendationid  voted_up  timestamp_created
# 0       147937429.0         1         1696875102
# 1       166664841.0         1         1717510100
